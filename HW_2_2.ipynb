# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-kondr/Data_Science_HW_2/blob/main/HW_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('2017_jun_final.csv')
df
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 0        1        Junior QA engineer                   NaN     Manual QA
# 1        2        Junior QA engineer                   NaN     Manual QA
# 2        3         Software Engineer               C#/.NET           NaN
# 3        4         Software Engineer            JavaScript           NaN
# 4        5  Senior Software Engineer            JavaScript           NaN
# ...    ...                       ...                   ...           ...
# 8699  8700               QA engineer                   NaN     Manual QA
# 8700  8701                 Marketing                   NaN           NaN
# 8701  8702  Junior Software Engineer            Ruby/Rails           NaN
# 8702  8703                 Team lead                   NaN           NaN
# 8703  8704  Senior Software Engineer                  Java           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# ...

# %% [markdown]
# Прочитайте отриману таблицю, використовуючи метод head

# %%
df.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %%
group_city = df.groupby('Город').agg({'Зарплата.в.месяц': 'mean'})
plt.plot(group_city.index, group_city['Зарплата.в.месяц'], label='Середня зарплата по містам')
plt.title('Середня зарплата')
plt.xticks(rotation=90)
plt.legend()
plt.grid()

# %% [markdown]
# Визначте розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (8704, 25)

# %% [markdown]
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
df.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
df.isnull().sum() / df.isnull().sum().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# ...

# %% [markdown]
# Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
df = df.drop(['Специализация', 'Университет', 'Предметная.область', 'Валюта', 'cls'],axis=1)

# %% [markdown]
# Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
df.isnull().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Еще.студент                            0
# Уровень.английского                    0
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# dtype: int64

# %% [markdown]
# Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
df = df.dropna()
df
# Out:
#          N                 Должность Язык.программирования Общий.опыт.работы  \
# 2        3         Software Engineer               C#/.NET                 4
# 3        4         Software Engineer            JavaScript                 5
# 4        5  Senior Software Engineer            JavaScript    10 и более лет
# 6        7  Junior Software Engineer               C#/.NET                 1
# 7        8  Senior Software Engineer                   C++                 6
# ...    ...                       ...                   ...               ...
# 8692  8693         Software Engineer                  Java                 5
# 8694  8695  Junior Software Engineer               C#/.NET                 1
# 8695  8696         Software Engineer                Python                 1
# 8701  8702  Junior Software Engineer            Ruby/Rails                 1
# 8703  8704  Senior Software Engineer                  Java                 7
#
# ...

# %%
group_by_language_gender = df.groupby(['Язык.программирования', 'Пол'])['Пол'].agg('count')
group_by_language_gender
# Out:
# Язык.программирования  Пол
# 1С                     мужской     42
# ABAP                   мужской      4
# APL                    мужской      1
# C                      мужской     54
# C#/.NET                женский     49
#                        мужской    783
# C++                    женский      7
#                        мужской    209
# Delphi                 мужской     17
# Erlang                 женский      1
#                        мужской      4
# Flex/Flash/AIR         женский      1
#                        мужской      4
# Golang                 мужской     21
# Haskell                женский      1
#                        мужской      3
# Java                   женский     50
#                        мужской    999
# JavaScript             женский     82
#                        мужской    941
# Objective-C            женский      4
#                        мужской     89
# Other                  женский      3
#                        мужской     50
# ...

# %%
group_by_language_gender.plot(kind='barh', figsize=(8, 10), color='red')
plt.title('Розподіл вибору мови програмування по статевою ознакою')
plt.grid()

# %%
group_by_language = df.groupby('Язык.программирования')['Зарплата.в.месяц'].mean()
group_by_language
# Out:
# Язык.программирования
# 1С                 941.142857
# ABAP              3025.000000
# APL               2250.000000
# C                 2037.685185
# C#/.NET           2084.525240
# C++               2398.194444
# Delphi            1265.647059
# Erlang            2520.000000
# Flex/Flash/AIR    2932.000000
# Golang            3043.333333
# Haskell           3850.000000
# Java              1970.929457
# JavaScript        1645.811339
# Objective-C       2028.602151
# Other             2318.396226
# PHP               1600.961298
# Perl              1907.142857
# Python            1753.937198
# Ruby/Rails        1932.766234
# SQL               2207.833333
# Scala             3204.980392
# Swift             1836.869565
# Name: Зарплата.в.месяц, dtype: float64

# %%
plt.bar(group_by_language.index, group_by_language, color='magenta')
plt.title('Розподіл середньою зарплати відносно мови програмування')
plt.xticks(rotation=90, color='blue')
plt.yticks(color='gray')
plt.ylabel('Середня зарплата', color='green')
plt.show()

# %% [markdown]
# Визначте новий розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (4854, 20)

# %% [markdown]
# Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = df[df['Язык.программирования'] == 'Python']
python_data
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 12      13         Software Engineer                Python           NaN
# 68      69         Software Engineer                Python           NaN
# 87      88  Junior Software Engineer                Python           NaN
# 114    115  Junior Software Engineer                Python           NaN
# 143    144  Junior Software Engineer                Python           NaN
# ...    ...                       ...                   ...           ...
# 8546  8547         Software Engineer                Python           NaN
# 8625  8626         Software Engineer                Python           NaN
# 8635  8636  Senior Software Engineer                Python           NaN
# 8673  8674  Junior Software Engineer                Python           NaN
# 8695  8696         Software Engineer                Python           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# ...

# %% [markdown]
# Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 20)

# %% [markdown]
# Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
position = python_data.groupby('Должность')
position

# %% [markdown]
# Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
position['Зарплата.в.месяц'].agg(min)
# Out:
#                              N Язык.программирования Общий.опыт.работы  \
# Должность
# Junior Software Engineer    88                Python              0.25
# Senior Software Engineer   303                Python    10 и более лет
# Software Engineer           13                Python              0.25
# System Architect          5749                Python    10 и более лет
# Technical Lead            2633                Python    10 и более лет
#
#                          Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# Должность
# Junior Software Engineer                         0.25               100
# Senior Software Engineer                         0.25              1300
# Software Engineer                                0.25               500
# System Architect                                 0.25              3000
# Technical Lead                                   0.25              1425
#
#                           Изменение.зарплаты.за.12.месяцев    Город  \
# ...

# %%
position['Зарплата.в.месяц'].agg(max)
# Out:
#                              N Язык.программирования Общий.опыт.работы  \
# Должность
# Junior Software Engineer  8674                Python  меньше 3 месяцев
# Senior Software Engineer  8636                Python                 9
# Software Engineer         8696                Python  меньше 3 месяцев
# System Architect          8229                Python    10 и более лет
# Technical Lead            8446                Python                 7
#
#                          Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# Должность
# Junior Software Engineer             меньше 3 месяцев              1250
# Senior Software Engineer             меньше 3 месяцев              9200
# Software Engineer                    меньше 3 месяцев              5400
# System Architect                                    2              5000
# Technical Lead                                      7              6200
#
#                           Изменение.зарплаты.за.12.месяцев        Город  \
# ...

# %% [markdown]
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
def fill_avg_salary(x):
    return x['Зарплата.в.месяц'].mean()

avg = position.apply(fill_avg_salary)
avg
# Out:
# Должность
# Junior Software Engineer     560.841270
# Senior Software Engineer    3387.096774
# Software Engineer           1799.070000
# System Architect            4000.000000
# Technical Lead              3165.909091
# dtype: float64

# %% [markdown]
# Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
avg.describe()
# Out:
# count       5.000000
# mean     2582.583427
# std      1387.255829
# min       560.841270
# 25%      1799.070000
# 50%      3165.909091
# 75%      3387.096774
# max      4000.000000
# dtype: float64

# %% [markdown]
# Збережіть отриману таблицю в CSV файл

# %%
avg.to_csv('avg.csv')
