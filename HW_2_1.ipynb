# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-kondr/Data_Science_HW_2/blob/main/HW_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Прочитайте дані за допомогою методу read_html з таблиці "Коефіцієнт народжуваності в регіонах України (1950—2019)"
#
# Замініть у таблиці значення "—" на значення NaN
#
# Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"

# %%
url = 'https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%80%D0%BE%D0%B4%D0%B6%D1%83%D0%B2%D0%B0%D0%BD%D1%96%D1%81%D1%82%D1%8C_%D0%B2_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96'

# %%
df = pd.read_html(url, decimal=',', thousands='.', match='Автономна Республіка Крим')[3]

# %%
df
# Out:
#                        регіон  1950  1960  1970  1990  1992  1994  1996  2000  \
# 0   Автономна Республіка Крим  23.0  20.6  16.0  13.0  10.9   9.3   8.0   7.3
# 1           Вінницька область  22.4  19.2  14.2  12.4  11.9  10.7  10.3   8.4
# 2           Волинська область  24.7  25.0  17.9  15.3  15.0  13.7  12.5  11.2
# 3    Дніпропетровська область  20.4  20.4  15.1  12.3  10.6   9.2   8.0   7.1
# 4            Донецька область  27.1  21.4  14.0  10.9   9.4   8.2   7.0   6.1
# 5         Житомирська область  26.1  22.3  15.9  12.9  12.8  11.8  10.8   8.9
# 6        Закарпатська область  31.4  27.3  20.7  16.8  16.1  13.8  12.8  11.5
# 7          Запорізька область  21.9  19.7  15.0  12.4  10.7   9.2   8.1   7.1
# 8   Івано-Франківська область  24.3  24.8  18.2  15.5  14.4  13.1  12.2  10.3
# 9            Київська область  20.4  18.9  15.6  12.3  11.1   9.9   9.2   7.3
# 10     Кіровоградська область  21.6  17.1  14.5  12.6  11.9  10.7   9.6   7.9
# ...

# %% [markdown]
# Вивести перші рядки таблиці за допомогою методу head

# %%
df.head()
# Out:
#                       регіон  1950  1960  1970  1990  1992  1994  1996  2000  \
# 0  Автономна Республіка Крим  23.0  20.6  16.0  13.0  10.9   9.3   8.0   7.3
# 1          Вінницька область  22.4  19.2  14.2  12.4  11.9  10.7  10.3   8.4
# 2          Волинська область  24.7  25.0  17.9  15.3  15.0  13.7  12.5  11.2
# 3   Дніпропетровська область  20.4  20.4  15.1  12.3  10.6   9.2   8.0   7.1
# 4           Донецька область  27.1  21.4  14.0  10.9   9.4   8.2   7.0   6.1
#
#    2004  2008  2012  2014
# 0   9.0  11.9  12.6   NaN
# 1   9.0  10.8  11.2  10.9
# 2  11.9  14.8  14.8  14.1
# 3   8.9  11.0  11.2  11.1
# 4   7.6   9.8   9.8   8.2

# %% [markdown]
# Визначте кількість рядків та стовпців у датафреймі (атрибут shape)

# %%
df.shape
# Out:
# (28, 13)

# %% [markdown]
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
df.dtypes
# Out:
# регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 1992      float64
# 1994      float64
# 1996      float64
# 2000      float64
# 2004      float64
# 2008      float64
# 2012      float64
# 2014      float64
# dtype: object

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
df.isnull().sum()
# Out:
# регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 1992      0
# 1994      0
# 1996      0
# 2000      0
# 2004      0
# 2008      0
# 2012      0
# 2014      2
# dtype: int64

# %% [markdown]
# Видаліть з таблиці дані по всій країні, останній рядок таблиці

# %%
df_new = df.drop([27])

# %%
df_new
# Out:
#                        регіон  1950  1960  1970  1990  1992  1994  1996  2000  \
# 0   Автономна Республіка Крим  23.0  20.6  16.0  13.0  10.9   9.3   8.0   7.3
# 1           Вінницька область  22.4  19.2  14.2  12.4  11.9  10.7  10.3   8.4
# 2           Волинська область  24.7  25.0  17.9  15.3  15.0  13.7  12.5  11.2
# 3    Дніпропетровська область  20.4  20.4  15.1  12.3  10.6   9.2   8.0   7.1
# 4            Донецька область  27.1  21.4  14.0  10.9   9.4   8.2   7.0   6.1
# 5         Житомирська область  26.1  22.3  15.9  12.9  12.8  11.8  10.8   8.9
# 6        Закарпатська область  31.4  27.3  20.7  16.8  16.1  13.8  12.8  11.5
# 7          Запорізька область  21.9  19.7  15.0  12.4  10.7   9.2   8.1   7.1
# 8   Івано-Франківська область  24.3  24.8  18.2  15.5  14.4  13.1  12.2  10.3
# 9            Київська область  20.4  18.9  15.6  12.3  11.1   9.9   9.2   7.3
# 10     Кіровоградська область  21.6  17.1  14.5  12.6  11.9  10.7   9.6   7.9
# ...

# %% [markdown]
# Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)

# %%
df_new = df_new.fillna({'1950': df_new['1950'].mean(), '1960': df_new['1960'].mean(), '1970': df_new['1970'].mean(), '2014': df_new['2014'].mean()})
df_new
# Out:
#                        регіон    1950       1960  1970  1990  1992  1994  \
# 0   Автономна Республіка Крим  23.000  20.600000  16.0  13.0  10.9   9.3
# 1           Вінницька область  22.400  19.200000  14.2  12.4  11.9  10.7
# 2           Волинська область  24.700  25.000000  17.9  15.3  15.0  13.7
# 3    Дніпропетровська область  20.400  20.400000  15.1  12.3  10.6   9.2
# 4            Донецька область  27.100  21.400000  14.0  10.9   9.4   8.2
# 5         Житомирська область  26.100  22.300000  15.9  12.9  12.8  11.8
# 6        Закарпатська область  31.400  27.300000  20.7  16.8  16.1  13.8
# 7          Запорізька область  21.900  19.700000  15.0  12.4  10.7   9.2
# 8   Івано-Франківська область  24.300  24.800000  18.2  15.5  14.4  13.1
# 9            Київська область  20.400  18.900000  15.6  12.3  11.1   9.9
# 10     Кіровоградська область  21.600  17.100000  14.5  12.6  11.9  10.7
# 11          Луганська область  26.200  23.500000  14.4  11.6  10.1   8.4
# ...

# %%
df_new.plot()
# Out:
# <Axes: >

# %% [markdown]
# Отримайте список регіонів, де рівень народжуваності у 2014 році був вищим за середній по Україні

# %%
df_new[['регіон', '2014']][df_new['2014'] > df_new['2014'].mean()]
# Out:
#                        регіон  2014
# 2           Волинська область  14.1
# 5         Житомирська область  12.0
# 6        Закарпатська область  14.6
# 8   Івано-Франківська область  12.2
# 9            Київська область  12.1
# 12          Львівська область  11.9
# 13       Миколаївська область  11.2
# 14            Одеська область  12.3
# 16         Рівненська область  14.8
# 20         Херсонська область  11.5
# 21        Хмельницька область  11.2
# 23        Чернівецька область  12.9
# 25                       Київ  12.1

# %% [markdown]
# У якому регіоні була найвища народжуваність у 2012 році?

# %%
df_new[['регіон', '2012']].max()
# Out:
# регіон    Чернігівська область
# 2012                      15.9
# dtype: object

# %% [markdown]
# Побудуйте стовпчикову діаграму народжуваності по регіонах у 2014 році

# %%
df_new = df_new.set_index(df_new['регіон'])
df_new.drop(['регіон'], axis=1)
# Out:
#                              1950       1960  1970  1990  1992  1994  1996  \
# регіон
# Автономна Республіка Крим  23.000  20.600000  16.0  13.0  10.9   9.3   8.0
# Вінницька область          22.400  19.200000  14.2  12.4  11.9  10.7  10.3
# Волинська область          24.700  25.000000  17.9  15.3  15.0  13.7  12.5
# Дніпропетровська область   20.400  20.400000  15.1  12.3  10.6   9.2   8.0
# Донецька область           27.100  21.400000  14.0  10.9   9.4   8.2   7.0
# Житомирська область        26.100  22.300000  15.9  12.9  12.8  11.8  10.8
# Закарпатська область       31.400  27.300000  20.7  16.8  16.1  13.8  12.8
# Запорізька область         21.900  19.700000  15.0  12.4  10.7   9.2   8.1
# Івано-Франківська область  24.300  24.800000  18.2  15.5  14.4  13.1  12.2
# Київська область           20.400  18.900000  15.6  12.3  11.1   9.9   9.2
# Кіровоградська область     21.600  17.100000  14.5  12.6  11.9  10.7   9.6
# ...

# %%
df_new['2014'].plot(kind='bar')
plt.show()

# %%
df_new['2014'].plot(kind='barh')
plt.grid()
